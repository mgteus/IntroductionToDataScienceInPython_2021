# %%
import re
def names():
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 3 kids."""

    # YOUR CODE HERE
    pattern = "([A-Z]{1}[a-z]+)"
    return re.findall(pattern, simple_string)
     
    #raise NotImplementedError()

assert len(names()) == 4, "There are four names in the simple_string"

# %%
simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
Ruth and Peter, their parents, have 3 kids."""
# YOUR CODE HERE
pattern = "([A-Z]{1}[a-z]+)"
re.findall(pattern, simple_string)

len(re.findall(pattern, simple_string))==4
# Out:
# True

# %%
import re

grades = """Ronald Mayr: A
Bell Kassulke: B
Jacqueline Rupp: A 
Alexander Zeller: C
Valentina Denk: C 
Simon Loidl: B 
Elias Jovanovic: B 
Stefanie Weninger: A 
Fabian Peer: C 
Hakim Botros: B
Emilie Lorentsen: B
Herman Karlsen: C
Nathalie Delacruz: C
Casey Hartman: C
Lily Walker : A
Gerard Wang: C
Tony Mcdowell: C
Jake Wood: B
Fatemeh Akhtar: B
Kim Weston: B
Nicholas Beatty: A
Kirsten Williams: C
Vaishali Surana: C
Coby Mccormack: C
Yasmin Dar: B
Romy Donnelly: A
Viswamitra Upandhye: B
Kendrick Hilpert: A
Killian Kaufman: B
Elwood Page: B
Mukti Patel: A
Emily Lesch: C
Elodie Booker: B
Jedd Kim: A
Annabel Davies: A
Adnan Chen: B
Jonathan Berg: C
Hank Spinka: B
Agnes Schneider: C
Kimberly Green: A
Lola-Rose Coates: C
Rose Christiansen: C
Shirley Hintz: C
Hannah Bayer: B
"""
#"(?P<names>[\w ]*)\:\s{1}(?P<grade>[\w]{1})" "([\w ]*)(?=\:\s{1})([\w]{1})"
pattern = "(?P<names>[\w ]*)\:\s{1}(?P<grade>[\w]{1})"
Blist = []


"""
def grades():
  for item in re.finditer(pattern, grades, re.VERBOSE):
    if str(item.group(2))== "B":
      Blist.append(str(item.group(1)))
 
    #print(item.group())
    #for i in item.group():
      #print(i)
  return Blist
"""
for item in re.finditer(pattern, grades, re.VERBOSE):
  if str(item.group(2))== "B":
    Blist.append(str(item.group(1)))
 
for i in Blist:
  print(i)

Blist


#for i in Blist:
 # print(i)


#grades()
#item
  #if item.group(3) == "B":
  #  print(item.group(1))
  #print(item.group(1) if item.group(3)=="B")
#print(re.findall(pattern, grades))

#len(re.findall(pattern, grades)) ==16
#grades.read()
# Out:
# ['Bell Kassulke',
#  'Simon Loidl',
#  'Elias Jovanovic',
#  'Hakim Botros',
#  'Emilie Lorentsen',
#  'Jake Wood',
#  'Fatemeh Akhtar',
#  'Kim Weston',
#  'Yasmin Dar',
#  'Viswamitra Upandhye',
#  'Killian Kaufman',
#  'Elwood Page',
#  'Elodie Booker',
#  'Adnan Chen',
#  'Hank Spinka',
#  'Hannah Bayer']

# %%
import re


logdata = r"""146.204.224.152 - feest6811 [21/Jun/2019:15:45:24 -0700] "POST /incentivize HTTP/1.1" 302 4622
197.109.77.178 - kertzmann3129 [21/Jun/2019:15:45:25 -0700] "DELETE /virtual/solutions/target/web+services HTTP/2.0" 203 26554
156.127.178.177 - okuneva5222 [21/Jun/2019:15:45:27 -0700] "DELETE /interactive/transparent/niches/revolutionize HTTP/1.1" 416 14701
100.32.205.59 - ortiz8891 [21/Jun/2019:15:45:28 -0700] "PATCH /architectures HTTP/1.0" 204 6048
168.95.156.240 - stark2413 [21/Jun/2019:15:45:31 -0700] "GET /engage HTTP/2.0" 201 9645
71.172.239.195 - dooley1853 [21/Jun/2019:15:45:32 -0700] "PUT /cutting-edge HTTP/2.0" 406 24498"""

#logdata = re.split("\n", logdata)
#logdata[0]
#len(logdata)
pattern = r""" 
(?P<host>\d+(?:\.\d+){3})
\s+\S+\s+ 
(?P<user_name>\S+)\s+\[
(?P<time>[^\]\[]*)\]\s+   
"(?P<request>[^"]*)" 
"""



#"(?P<host>[\d\.]*)(?P<request>[A-Z]*([\w ]*))"

  



#(?P<user_name>[-\w]*)
for item in re.finditer(pattern, logdata, re.VERBOSE):
    print(item.groupdict())
# Out:
# {'host': '146.204.224.152', 'user_name': 'feest6811', 'time': '21/Jun/2019:15:45:24 -0700', 'request': 'POST /incentivize HTTP/1.1'}
# {'host': '197.109.77.178', 'user_name': 'kertzmann3129', 'time': '21/Jun/2019:15:45:25 -0700', 'request': 'DELETE /virtual/solutions/target/web+services HTTP/2.0'}
# {'host': '156.127.178.177', 'user_name': 'okuneva5222', 'time': '21/Jun/2019:15:45:27 -0700', 'request': 'DELETE /interactive/transparent/niches/revolutionize HTTP/1.1'}
# {'host': '100.32.205.59', 'user_name': 'ortiz8891', 'time': '21/Jun/2019:15:45:28 -0700', 'request': 'PATCH /architectures HTTP/1.0'}
# {'host': '168.95.156.240', 'user_name': 'stark2413', 'time': '21/Jun/2019:15:45:31 -0700', 'request': 'GET /engage HTTP/2.0'}
# {'host': '71.172.239.195', 'user_name': 'dooley1853', 'time': '21/Jun/2019:15:45:32 -0700', 'request': 'PUT /cutting-edge HTTP/2.0'}

# %%
import re

pattern = r""" 
                        (?P<host>\d+(?:\.\d+){3})
                        \s+\S+\s+ 
                        (?P<user_name>\S+)\s+\[
                        (?P<time>[^\]\[]*)\]\s+   
                        "(?P<request>[^"]*)" 
                        """

def logs():
    with open("/content/drive/MyDrive/Cursos/Cousera/Intro. to Data Science in Python/logdata.txt", "r") as file:
        logdata = file.read()
        
        for item in re.finditer(pattern, logdata, re.VERBOSE):
          
            
            
    return item.groupdict()


len(logs())


one_item={'host': '146.204.224.152',
  'user_name': 'feest6811',
  'time': '21/Jun/2019:15:45:24 -0700',
  'request': 'POST /incentivize HTTP/1.1'}


one_item in logs(),
# Out:
#   File "<ipython-input-45-9983d8a31bf2>", line 19
#     return item.groupdict()
#     ^
# IndentationError: expected an indented block
